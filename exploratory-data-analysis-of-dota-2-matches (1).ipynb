# %% [markdown]
# # Exploratory Data Analysis of DotA 2 Matches

# %% [markdown]
# Thank you to Kaggle user [Defne Ozturk](https://www.kaggle.com/defneztrk/data-visualization) for publishing their code and allowing others to post edits and learn.
#
# This project is a continual work-in-progress! I'm looking to add more interesting analysis topics later, specifically around predicting item timings from hero picks, as well as predicting match results from item choices and hero picks!

# %%
#Importing everyone's favorite libraries and getting our data

import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/dota-2-matches/players.csv
# /kaggle/input/dota-2-matches/ability_upgrades.csv
# /kaggle/input/dota-2-matches/test_player.csv
# /kaggle/input/dota-2-matches/match_outcomes.csv
# /kaggle/input/dota-2-matches/teamfights_players.csv
# /kaggle/input/dota-2-matches/chat.csv
# /kaggle/input/dota-2-matches/purchase_log.csv
# /kaggle/input/dota-2-matches/test_labels.csv
# /kaggle/input/dota-2-matches/ability_ids.csv
# /kaggle/input/dota-2-matches/item_ids.csv
# /kaggle/input/dota-2-matches/player_time.csv
# /kaggle/input/dota-2-matches/patch_dates.csv
# /kaggle/input/dota-2-matches/yasp_sample.json
# /kaggle/input/dota-2-matches/match.csv
# /kaggle/input/dota-2-matches/player_ratings.csv
# /kaggle/input/dota-2-matches/hero_names.csv
# /kaggle/input/dota-2-matches/cluster_regions.csv
# /kaggle/input/dota-2-matches/teamfights.csv
# /kaggle/input/dota-2-matches/objectives.csv

# %%
#Importing our CSVs

games = pd.read_csv("../input/dota-2-matches/players.csv")
heroes = pd.read_csv("../input/dota-2-matches/hero_names.csv")
match_results = pd.read_csv("../input/dota-2-matches/match.csv")
item_names = pd.read_csv("../input/dota-2-matches/item_ids.csv")
purchases = pd.read_csv("../input/dota-2-matches/purchase_log.csv")
player_ratings = pd.read_csv("../input/dota-2-matches/player_ratings.csv")

# %%
#Painting a picture of our datatypes 

games.head()
# Out:
#    match_id  account_id  hero_id  player_slot  gold  gold_spent  gold_per_min  \
# 0         0           0       86            0  3261       10960           347
# 1         0           1       51            1  2954       17760           494
# 2         0           0       83            2   110       12195           350
# 3         0           2       11            3  1179       22505           599
# 4         0           3       67            4  3307       23825           613
#
#    xp_per_min  kills  deaths  ...  unit_order_glyph  \
# 0         362      9       3  ...               NaN
# 1         659     13       3  ...               NaN
# 2         385      0       4  ...               NaN
# 3         605      8       4  ...               1.0
# 4         762     20       3  ...               3.0
#
#    unit_order_eject_item_from_stash  unit_order_cast_rune  \
# 0                               NaN                   NaN
# 1                               NaN                   NaN
# 2                               NaN                   NaN
# 3                               NaN                   NaN
# 4                               NaN                   NaN
#
#   unit_order_ping_ability  unit_order_move_to_direction  unit_order_patrol  \
# 0                     6.0                           NaN                NaN
# 1                    14.0                           NaN                NaN
# 2                    17.0                           NaN                NaN
# 3                    13.0                           NaN                NaN
# 4                    23.0                           NaN                NaN
#
#    unit_order_vector_target_position  unit_order_radar  \
# 0                                NaN               NaN
# 1                                NaN               NaN
# 2                                NaN               NaN
# 3                                NaN               NaN
# 4                                NaN               NaN
#
#    unit_order_set_item_combine_lock  unit_order_continue
# 0                               NaN                  NaN
# 1                               NaN                  NaN
# 2                               NaN                  NaN
# 3                               NaN                  NaN
# 4                               NaN                  NaN
#
# [5 rows x 73 columns]

# %%
games.shape
# Out:
# (500000, 73)

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 73 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   match_id                           500000 non-null  int64
#  1   account_id                         500000 non-null  int64
#  2   hero_id                            500000 non-null  int64
#  3   player_slot                        500000 non-null  int64
#  4   gold                               500000 non-null  int64
#  5   gold_spent                         500000 non-null  int64
#  6   gold_per_min                       500000 non-null  int64
#  7   xp_per_min                         500000 non-null  int64
#  8   kills                              500000 non-null  int64
#  9   deaths                             500000 non-null  int64
#  10  assists                            500000 non-null  int64
#  11  denies                             500000 non-null  int64
#  12  last_hits                          500000 non-null  int64
#  13  stuns                              500000 non-null  object
#  14  hero_damage                        500000 non-null  int64
#  15  hero_healing                       500000 non-null  int64
#  16  tower_damage                       500000 non-null  int64
#  17  item_0                             500000 non-null  int64
#  18  item_1                             500000 non-null  int64
#  19  item_2                             500000 non-null  int64
#  20  item_3                             500000 non-null  int64
#  21  item_4                             500000 non-null  int64
#  22  item_5                             500000 non-null  int64
#  23  level                              500000 non-null  int64
#  24  leaver_status                      500000 non-null  int64
#  25  xp_hero                            498117 non-null  float64
#  26  xp_creep                           499932 non-null  float64
#  27  xp_roshan                          179562 non-null  float64
#  28  xp_other                           478964 non-null  float64
#  29  gold_other                         405103 non-null  float64
#  30  gold_death                         493701 non-null  float64
#  31  gold_buyback                       147141 non-null  float64
#  32  gold_abandon                       20634 non-null   float64
#  33  gold_sell                          397407 non-null  float64
#  34  gold_destroying_structure          480325 non-null  float64
#  35  gold_killing_heros                 498435 non-null  float64
#  36  gold_killing_creeps                499706 non-null  float64
#  37  gold_killing_roshan                259736 non-null  float64
#  38  gold_killing_couriers              96979 non-null   float64
#  39  unit_order_none                    6 non-null       float64
#  40  unit_order_move_to_position        499958 non-null  float64
#  41  unit_order_move_to_target          445450 non-null  float64
#  42  unit_order_attack_move             386729 non-null  float64
#  43  unit_order_attack_target           499895 non-null  float64
#  44  unit_order_cast_position           497731 non-null  float64
#  45  unit_order_cast_target             483326 non-null  float64
#  46  unit_order_cast_target_tree        464288 non-null  float64
#  47  unit_order_cast_no_target          499108 non-null  float64
#  48  unit_order_cast_toggle             98789 non-null   float64
#  49  unit_order_hold_position           362723 non-null  float64
#  50  unit_order_train_ability           499927 non-null  float64
#  51  unit_order_drop_item               211333 non-null  float64
#  52  unit_order_give_item               105369 non-null  float64
#  53  unit_order_pickup_item             255342 non-null  float64
#  54  unit_order_pickup_rune             425483 non-null  float64
#  55  unit_order_purchase_item           499943 non-null  float64
#  56  unit_order_sell_item               388134 non-null  float64
#  57  unit_order_disassemble_item        14554 non-null   float64
#  58  unit_order_move_item               495736 non-null  float64
#  59  unit_order_cast_toggle_auto        36330 non-null   float64
#  60  unit_order_stop                    87575 non-null   float64
#  61  unit_order_taunt                   0 non-null       float64
#  62  unit_order_buyback                 147767 non-null  float64
#  63  unit_order_glyph                   226770 non-null  float64
#  64  unit_order_eject_item_from_stash   31264 non-null   float64
#  65  unit_order_cast_rune               9 non-null       float64
#  66  unit_order_ping_ability            339148 non-null  float64
#  67  unit_order_move_to_direction       3551 non-null    float64
#  68  unit_order_patrol                  0 non-null       float64
#  69  unit_order_vector_target_position  0 non-null       float64
#  70  unit_order_radar                   0 non-null       float64
#  71  unit_order_set_item_combine_lock   0 non-null       float64
#  72  unit_order_continue                0 non-null       float64
# dtypes: float64(48), int64(24), object(1)
# memory usage: 278.5+ MB

# %%
#We can see that we have a good amount of NaN values - let's change these to 0s to clean things up.

games = games.fillna(0)

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 73 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   match_id                           500000 non-null  int64
#  1   account_id                         500000 non-null  int64
#  2   hero_id                            500000 non-null  int64
#  3   player_slot                        500000 non-null  int64
#  4   gold                               500000 non-null  int64
#  5   gold_spent                         500000 non-null  int64
#  6   gold_per_min                       500000 non-null  int64
#  7   xp_per_min                         500000 non-null  int64
#  8   kills                              500000 non-null  int64
#  9   deaths                             500000 non-null  int64
#  10  assists                            500000 non-null  int64
#  11  denies                             500000 non-null  int64
#  12  last_hits                          500000 non-null  int64
#  13  stuns                              500000 non-null  object
#  14  hero_damage                        500000 non-null  int64
#  15  hero_healing                       500000 non-null  int64
#  16  tower_damage                       500000 non-null  int64
#  17  item_0                             500000 non-null  int64
#  18  item_1                             500000 non-null  int64
#  19  item_2                             500000 non-null  int64
#  20  item_3                             500000 non-null  int64
#  21  item_4                             500000 non-null  int64
#  22  item_5                             500000 non-null  int64
#  23  level                              500000 non-null  int64
#  24  leaver_status                      500000 non-null  int64
#  25  xp_hero                            500000 non-null  float64
#  26  xp_creep                           500000 non-null  float64
#  27  xp_roshan                          500000 non-null  float64
#  28  xp_other                           500000 non-null  float64
#  29  gold_other                         500000 non-null  float64
#  30  gold_death                         500000 non-null  float64
#  31  gold_buyback                       500000 non-null  float64
#  32  gold_abandon                       500000 non-null  float64
#  33  gold_sell                          500000 non-null  float64
#  34  gold_destroying_structure          500000 non-null  float64
#  35  gold_killing_heros                 500000 non-null  float64
#  36  gold_killing_creeps                500000 non-null  float64
#  37  gold_killing_roshan                500000 non-null  float64
#  38  gold_killing_couriers              500000 non-null  float64
#  39  unit_order_none                    500000 non-null  float64
#  40  unit_order_move_to_position        500000 non-null  float64
#  41  unit_order_move_to_target          500000 non-null  float64
#  42  unit_order_attack_move             500000 non-null  float64
#  43  unit_order_attack_target           500000 non-null  float64
#  44  unit_order_cast_position           500000 non-null  float64
#  45  unit_order_cast_target             500000 non-null  float64
#  46  unit_order_cast_target_tree        500000 non-null  float64
#  47  unit_order_cast_no_target          500000 non-null  float64
#  48  unit_order_cast_toggle             500000 non-null  float64
#  49  unit_order_hold_position           500000 non-null  float64
#  50  unit_order_train_ability           500000 non-null  float64
#  51  unit_order_drop_item               500000 non-null  float64
#  52  unit_order_give_item               500000 non-null  float64
#  53  unit_order_pickup_item             500000 non-null  float64
#  54  unit_order_pickup_rune             500000 non-null  float64
#  55  unit_order_purchase_item           500000 non-null  float64
#  56  unit_order_sell_item               500000 non-null  float64
#  57  unit_order_disassemble_item        500000 non-null  float64
#  58  unit_order_move_item               500000 non-null  float64
#  59  unit_order_cast_toggle_auto        500000 non-null  float64
#  60  unit_order_stop                    500000 non-null  float64
#  61  unit_order_taunt                   500000 non-null  float64
#  62  unit_order_buyback                 500000 non-null  float64
#  63  unit_order_glyph                   500000 non-null  float64
#  64  unit_order_eject_item_from_stash   500000 non-null  float64
#  65  unit_order_cast_rune               500000 non-null  float64
#  66  unit_order_ping_ability            500000 non-null  float64
#  67  unit_order_move_to_direction       500000 non-null  float64
#  68  unit_order_patrol                  500000 non-null  float64
#  69  unit_order_vector_target_position  500000 non-null  float64
#  70  unit_order_radar                   500000 non-null  float64
#  71  unit_order_set_item_combine_lock   500000 non-null  float64
#  72  unit_order_continue                500000 non-null  float64
# dtypes: float64(48), int64(24), object(1)
# memory usage: 278.5+ MB

# %%
#What does our heroes table look like?
heroes.head()

#Gives us dimensions of the table, we can see our table has 112 rows with 3 columns --> 112 heroes with 3 pieces of information.

heroes.shape

#And what sort of datatypes are we working with?

heroes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            112 non-null    object
#  1   hero_id         112 non-null    int64
#  2   localized_name  112 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 2.8+ KB

# %%
#Let's take a look at our match results table next. 

match_results.head()
# Out:
#    match_id  start_time  duration  tower_status_radiant  tower_status_dire  \
# 0         0  1446750112      2375                  1982                  4
# 1         1  1446753078      2582                     0               1846
# 2         2  1446764586      2716                   256               1972
# 3         3  1446765723      3085                     4               1924
# 4         4  1446796385      1887                  2047                  0
#
#    barracks_status_dire  barracks_status_radiant  first_blood_time  game_mode  \
# 0                     3                       63                 1         22
# 1                    63                        0               221         22
# 2                    63                       48               190         22
# 3                    51                        3                40         22
# 4                     0                       63                58         22
#
#    radiant_win  negative_votes  positive_votes  cluster
# 0         True               0               1      155
# 1        False               0               2      154
# 2        False               0               0      132
# 3        False               0               0      191
# 4         True               0               0      156

# %%
match_results.head()
# Out:
#    match_id  start_time  duration  tower_status_radiant  tower_status_dire  \
# 0         0  1446750112      2375                  1982                  4
# 1         1  1446753078      2582                     0               1846
# 2         2  1446764586      2716                   256               1972
# 3         3  1446765723      3085                     4               1924
# 4         4  1446796385      1887                  2047                  0
#
#    barracks_status_dire  barracks_status_radiant  first_blood_time  game_mode  \
# 0                     3                       63                 1         22
# 1                    63                        0               221         22
# 2                    63                       48               190         22
# 3                    51                        3                40         22
# 4                     0                       63                58         22
#
#    radiant_win  negative_votes  positive_votes  cluster
# 0         True               0               1      155
# 1        False               0               2      154
# 2        False               0               0      132
# 3        False               0               0      191
# 4         True               0               0      156

# %%
match_results.shape
# Out:
# (50000, 13)

# %%
match_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   match_id                 50000 non-null  int64
#  1   start_time               50000 non-null  int64
#  2   duration                 50000 non-null  int64
#  3   tower_status_radiant     50000 non-null  int64
#  4   tower_status_dire        50000 non-null  int64
#  5   barracks_status_dire     50000 non-null  int64
#  6   barracks_status_radiant  50000 non-null  int64
#  7   first_blood_time         50000 non-null  int64
#  8   game_mode                50000 non-null  int64
#  9   radiant_win              50000 non-null  bool
#  10  negative_votes           50000 non-null  int64
#  11  positive_votes           50000 non-null  int64
#  12  cluster                  50000 non-null  int64
# dtypes: bool(1), int64(12)
# memory usage: 4.6 MB

# %%
item_names.head()
# Out:
#    item_id         item_name
# 0        1             blink
# 1        2  blades_of_attack
# 2        3        broadsword
# 3        4         chainmail
# 4        5          claymore

# %%
item_names.shape
# Out:
# (189, 2)

# %%
item_names.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   item_id    189 non-null    int64
#  1   item_name  189 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 3.1+ KB

# %%
purchases.head()
# Out:
#    item_id  time  player_slot  match_id
# 0       44   -81            0         0
# 1       29   -63            0         0
# 2       43     6            0         0
# 3       84   182            0         0
# 4       46   197            0         0

# %%
purchases.shape
# Out:
# (18193745, 4)

# %%
purchases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18193745 entries, 0 to 18193744
# Data columns (total 4 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   item_id      int64
#  1   time         int64
#  2   player_slot  int64
#  3   match_id     int64
# dtypes: int64(4)
# memory usage: 555.2 MB

# %%
player_ratings.head()
# Out:
#    account_id  total_wins  total_matches  trueskill_mu  trueskill_sigma
# 0      236579          14             24     27.868035         5.212361
# 1        -343           1              1     26.544163         8.065475
# 2       -1217           1              1     26.521103         8.114989
# 3       -1227           1              1     27.248025         8.092217
# 4       -1284           0              1     22.931016         8.092224

# %%
player_ratings.shape
# Out:
# (834226, 5)

# %%
player_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 834226 entries, 0 to 834225
# Data columns (total 5 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   account_id       834226 non-null  int64
#  1   total_wins       834226 non-null  int64
#  2   total_matches    834226 non-null  int64
#  3   trueskill_mu     834226 non-null  float64
#  4   trueskill_sigma  834226 non-null  float64
# dtypes: float64(2), int64(3)
# memory usage: 31.8 MB

# %%
#Constructing a separate table for unit orders. We may not need this, but it might be interesting in further analysis. 

unit_orders = pd.read_csv("../input/dota-2-matches/players.csv")



unit_orders.head()
# Out:
#    match_id  account_id  hero_id  player_slot  gold  gold_spent  gold_per_min  \
# 0         0           0       86            0  3261       10960           347
# 1         0           1       51            1  2954       17760           494
# 2         0           0       83            2   110       12195           350
# 3         0           2       11            3  1179       22505           599
# 4         0           3       67            4  3307       23825           613
#
#    xp_per_min  kills  deaths  ...  unit_order_glyph  \
# 0         362      9       3  ...               NaN
# 1         659     13       3  ...               NaN
# 2         385      0       4  ...               NaN
# 3         605      8       4  ...               1.0
# 4         762     20       3  ...               3.0
#
#    unit_order_eject_item_from_stash  unit_order_cast_rune  \
# 0                               NaN                   NaN
# 1                               NaN                   NaN
# 2                               NaN                   NaN
# 3                               NaN                   NaN
# 4                               NaN                   NaN
#
#   unit_order_ping_ability  unit_order_move_to_direction  unit_order_patrol  \
# 0                     6.0                           NaN                NaN
# 1                    14.0                           NaN                NaN
# 2                    17.0                           NaN                NaN
# 3                    13.0                           NaN                NaN
# 4                    23.0                           NaN                NaN
#
#    unit_order_vector_target_position  unit_order_radar  \
# 0                                NaN               NaN
# 1                                NaN               NaN
# 2                                NaN               NaN
# 3                                NaN               NaN
# 4                                NaN               NaN
#
#    unit_order_set_item_combine_lock  unit_order_continue
# 0                               NaN                  NaN
# 1                               NaN                  NaN
# 2                               NaN                  NaN
# 3                               NaN                  NaN
# 4                               NaN                  NaN
#
# [5 rows x 73 columns]

# %% [markdown]
# Indexing columns of the Games table

# %%
#Trimming the games table to exclude unit orders.

games = games.iloc[:,:39]

games.head()
# Out:
#    match_id  account_id  hero_id  player_slot  gold  gold_spent  gold_per_min  \
# 0         0           0       86            0  3261       10960           347
# 1         0           1       51            1  2954       17760           494
# 2         0           0       83            2   110       12195           350
# 3         0           2       11            3  1179       22505           599
# 4         0           3       67            4  3307       23825           613
#
#    xp_per_min  kills  deaths  ...  gold_other  gold_death  gold_buyback  \
# 0         362      9       3  ...        50.0      -957.0           0.0
# 1         659     13       3  ...       395.0     -1137.0           0.0
# 2         385      0       4  ...       259.0     -1436.0       -1015.0
# 3         605      8       4  ...       100.0     -2156.0           0.0
# 4         762     20       3  ...         0.0     -1437.0       -1056.0
#
#   gold_abandon  gold_sell  gold_destroying_structure  gold_killing_heros  \
# 0          0.0      212.0                     3120.0              5145.0
# 1          0.0     1650.0                     3299.0              6676.0
# 2          0.0        0.0                     3142.0              2418.0
# 3          0.0      938.0                     4714.0              4104.0
# 4          0.0     4194.0                     3217.0              7467.0
#
#    gold_killing_creeps  gold_killing_roshan  gold_killing_couriers
# 0               1087.0                400.0                    0.0
# 1               4317.0                937.0                    0.0
# 2               3697.0                400.0                    0.0
# 3              10432.0                400.0                    0.0
# 4               9220.0                400.0                    0.0
#
# [5 rows x 39 columns]

# %%
#Using pandas .iloc to select which rows and columns we want to look at. [:, -2:] indicates 

heroes = heroes.iloc[:,-2:]
heroes.head()

hero1 = heroes.iloc[0]
print(hero1)
# Out:
# hero_id                   1
# localized_name    Anti-Mage
# Name: 0, dtype: object

# %%
match_results = match_results.iloc[:,:10]
match_results.head()
# Out:
#    match_id  start_time  duration  tower_status_radiant  tower_status_dire  \
# 0         0  1446750112      2375                  1982                  4
# 1         1  1446753078      2582                     0               1846
# 2         2  1446764586      2716                   256               1972
# 3         3  1446765723      3085                     4               1924
# 4         4  1446796385      1887                  2047                  0
#
#    barracks_status_dire  barracks_status_radiant  first_blood_time  game_mode  \
# 0                     3                       63                 1         22
# 1                    63                        0               221         22
# 2                    63                       48               190         22
# 3                    51                        3                40         22
# 4                     0                       63                58         22
#
#    radiant_win
# 0         True
# 1        False
# 2        False
# 3        False
# 4         True

# %%
player_ratings = player_ratings.iloc[:,:3]
player_ratings.head()
# Out:
#    account_id  total_wins  total_matches
# 0      236579          14             24
# 1        -343           1              1
# 2       -1217           1              1
# 3       -1227           1              1
# 4       -1284           0              1

# %%
full = pd.merge(heroes, games, how="left", left_on="hero_id", right_on="hero_id")
full.head(10)
# Out:
#    hero_id localized_name  match_id  account_id  player_slot    gold  \
# 0        1      Anti-Mage      12.0         0.0        130.0  1554.0
# 1        1      Anti-Mage      14.0         0.0          1.0  1941.0
# 2        1      Anti-Mage      21.0       123.0          4.0  7554.0
# 3        1      Anti-Mage      23.0       135.0          3.0  9515.0
# 4        1      Anti-Mage      25.0         0.0        132.0   979.0
# 5        1      Anti-Mage      28.0         0.0          1.0  6158.0
# 6        1      Anti-Mage      44.0       247.0          2.0  5537.0
# 7        1      Anti-Mage      47.0         0.0          1.0   684.0
# 8        1      Anti-Mage      49.0         0.0        129.0  2749.0
# 9        1      Anti-Mage      56.0       316.0          3.0  2892.0
#
#    gold_spent  gold_per_min  xp_per_min  kills  ...  gold_other  gold_death  \
# 0     39915.0         688.0       487.0   17.0  ...       308.0     -6410.0
# 1     11785.0         500.0       377.0    4.0  ...        10.0     -1645.0
# 2     15325.0         665.0       583.0   12.0  ...       198.0      -957.0
# 3     21925.0         678.0       712.0    9.0  ...       358.0     -1225.0
# 4     12500.0         392.0       446.0    2.0  ...         0.0     -3263.0
# 5     22935.0         795.0       755.0   16.0  ...       219.0     -1046.0
# 6     36700.0         597.0       447.0    7.0  ...       668.0     -3713.0
# 7     16550.0         565.0       510.0    5.0  ...       194.0      -328.0
# 8     19450.0         572.0       616.0    5.0  ...         0.0     -2813.0
# 9     24105.0         550.0       553.0   16.0  ...       651.0     -5270.0
#
#    gold_buyback  gold_abandon gold_sell  gold_destroying_structure  \
# 0       -1888.0           0.0    2199.0                     3566.0
# 1           0.0           0.0     125.0                     3631.0
# 2           0.0           0.0     525.0                     4664.0
# 3           0.0           0.0    1050.0                     5333.0
# 4        -202.0           0.0    1200.0                      645.0
# 5           0.0           0.0     350.0                     5638.0
# 6           0.0           0.0    1199.0                     4380.0
# 7           0.0           0.0    2075.0                     4157.0
# 8           0.0        1336.0     800.0                     1275.0
# 9       -3150.0           0.0    1362.0                     2851.0
#
#    gold_killing_heros  gold_killing_creeps  gold_killing_roshan  \
# 0              9798.0              23596.0               1762.0
# 1              1654.0               5898.0                200.0
# 2              4380.0               9296.0                502.0
# 3              4750.0              15628.0                  0.0
# 4               804.0              10391.0                  0.0
# 5              5597.0              13857.0                200.0
# 6              4304.0              26313.0                400.0
# 7              2465.0               4806.0                400.0
# 8              4932.0              11300.0                  0.0
# 9             13503.0               9238.0                  0.0
#
#    gold_killing_couriers
# 0                  175.0
# 1                  150.0
# 2                    0.0
# 3                  350.0
# 4                    0.0
# 5                    0.0
# 6                    0.0
# 7                  150.0
# 8                    0.0
# 9                  175.0
#
# [10 rows x 40 columns]

# %%
full.tail(10)
# Out:
#         hero_id localized_name  match_id  account_id  player_slot    gold  \
# 499955      112  Winter Wyvern   49930.0    158214.0          1.0   208.0
# 499956      112  Winter Wyvern   49939.0     60376.0          4.0  1182.0
# 499957      112  Winter Wyvern   49944.0    158258.0          4.0  3050.0
# 499958      112  Winter Wyvern   49958.0    139136.0        131.0  2825.0
# 499959      112  Winter Wyvern   49967.0     60979.0          3.0  2558.0
# 499960      112  Winter Wyvern   49968.0         0.0        130.0   212.0
# 499961      112  Winter Wyvern   49977.0      3901.0          2.0  1078.0
# 499962      112  Winter Wyvern   49995.0    158352.0        132.0  2190.0
# 499963      112  Winter Wyvern   49996.0         0.0        130.0   201.0
# 499964      113     Arc Warden       NaN         NaN          NaN     NaN
#
#         gold_spent  gold_per_min  xp_per_min  kills  ...  gold_other  \
# 499955      8270.0         216.0       227.0    2.0  ...        50.0
# 499956      6285.0         264.0       248.0    3.0  ...         0.0
# 499957      8275.0         272.0       326.0    1.0  ...       421.0
# 499958      9885.0         279.0       292.0    2.0  ...       357.0
# 499959     16905.0         311.0       352.0   11.0  ...       206.0
# 499960      7175.0         188.0       222.0    1.0  ...        50.0
# 499961     11840.0         324.0       375.0    6.0  ...       322.0
# 499962      8635.0         254.0       275.0    1.0  ...       198.0
# 499963      2335.0         142.0       121.0    0.0  ...       150.0
# 499964         NaN           NaN         NaN    NaN  ...         NaN
#
#         gold_death  gold_buyback  gold_abandon gold_sell  \
# 499955     -2989.0           0.0           0.0       0.0
# 499956     -2510.0        -730.0           0.0       0.0
# 499957     -2482.0           0.0           0.0      25.0
# 499958     -2180.0           0.0           0.0     262.0
# 499959     -2273.0       -1348.0           0.0     232.0
# 499960     -4575.0           0.0           0.0      75.0
# 499961     -3589.0           0.0           0.0      75.0
# 499962     -1944.0        -602.0           0.0     350.0
# 499963     -1789.0           0.0           0.0       0.0
# 499964         NaN           NaN           NaN       NaN
#
#         gold_destroying_structure  gold_killing_heros  gold_killing_creeps  \
# 499955                     1126.0              2652.0               1636.0
# 499956                     1260.0              3741.0                544.0
# 499957                     3974.0              2314.0                981.0
# 499958                     3808.0              3045.0               1745.0
# 499959                     3356.0              7277.0               3359.0
# 499960                      880.0              1808.0               1868.0
# 499961                     3780.0              4357.0                855.0
# 499962                     1320.0              3269.0               2991.0
# 499963                      320.0               249.0                320.0
# 499964                        NaN                 NaN                  NaN
#
#         gold_killing_roshan  gold_killing_couriers
# 499955                  0.0                    0.0
# 499956                  0.0                    0.0
# 499957                200.0                    0.0
# 499958                400.0                    0.0
# 499959                  0.0                  350.0
# 499960                200.0                    0.0
# 499961                200.0                    0.0
# 499962                  0.0                    0.0
# 499963                  0.0                    0.0
# 499964                  NaN                    NaN
#
# [10 rows x 40 columns]

# %%
full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 499965 entries, 0 to 499964
# Data columns (total 40 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   hero_id                    499965 non-null  int64
#  1   localized_name             499965 non-null  object
#  2   match_id                   499963 non-null  float64
#  3   account_id                 499963 non-null  float64
#  4   player_slot                499963 non-null  float64
#  5   gold                       499963 non-null  float64
#  6   gold_spent                 499963 non-null  float64
#  7   gold_per_min               499963 non-null  float64
#  8   xp_per_min                 499963 non-null  float64
#  9   kills                      499963 non-null  float64
#  10  deaths                     499963 non-null  float64
#  11  assists                    499963 non-null  float64
#  12  denies                     499963 non-null  float64
#  13  last_hits                  499963 non-null  float64
#  14  stuns                      499963 non-null  object
#  15  hero_damage                499963 non-null  float64
#  16  hero_healing               499963 non-null  float64
#  17  tower_damage               499963 non-null  float64
#  18  item_0                     499963 non-null  float64
#  19  item_1                     499963 non-null  float64
#  20  item_2                     499963 non-null  float64
#  21  item_3                     499963 non-null  float64
#  22  item_4                     499963 non-null  float64
#  23  item_5                     499963 non-null  float64
#  24  level                      499963 non-null  float64
#  25  leaver_status              499963 non-null  float64
#  26  xp_hero                    499963 non-null  float64
#  27  xp_creep                   499963 non-null  float64
#  28  xp_roshan                  499963 non-null  float64
#  29  xp_other                   499963 non-null  float64
#  30  gold_other                 499963 non-null  float64
#  31  gold_death                 499963 non-null  float64
#  32  gold_buyback               499963 non-null  float64
#  33  gold_abandon               499963 non-null  float64
#  34  gold_sell                  499963 non-null  float64
#  35  gold_destroying_structure  499963 non-null  float64
#  36  gold_killing_heros         499963 non-null  float64
#  37  gold_killing_creeps        499963 non-null  float64
#  38  gold_killing_roshan        499963 non-null  float64
#  39  gold_killing_couriers      499963 non-null  float64
# dtypes: float64(37), int64(1), object(2)
# memory usage: 156.4+ MB

# %%
full = full[full['match_id'].notna()]
full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 499963 entries, 0 to 499963
# Data columns (total 40 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   hero_id                    499963 non-null  int64
#  1   localized_name             499963 non-null  object
#  2   match_id                   499963 non-null  float64
#  3   account_id                 499963 non-null  float64
#  4   player_slot                499963 non-null  float64
#  5   gold                       499963 non-null  float64
#  6   gold_spent                 499963 non-null  float64
#  7   gold_per_min               499963 non-null  float64
#  8   xp_per_min                 499963 non-null  float64
#  9   kills                      499963 non-null  float64
#  10  deaths                     499963 non-null  float64
#  11  assists                    499963 non-null  float64
#  12  denies                     499963 non-null  float64
#  13  last_hits                  499963 non-null  float64
#  14  stuns                      499963 non-null  object
#  15  hero_damage                499963 non-null  float64
#  16  hero_healing               499963 non-null  float64
#  17  tower_damage               499963 non-null  float64
#  18  item_0                     499963 non-null  float64
#  19  item_1                     499963 non-null  float64
#  20  item_2                     499963 non-null  float64
#  21  item_3                     499963 non-null  float64
#  22  item_4                     499963 non-null  float64
#  23  item_5                     499963 non-null  float64
#  24  level                      499963 non-null  float64
#  25  leaver_status              499963 non-null  float64
#  26  xp_hero                    499963 non-null  float64
#  27  xp_creep                   499963 non-null  float64
#  28  xp_roshan                  499963 non-null  float64
#  29  xp_other                   499963 non-null  float64
#  30  gold_other                 499963 non-null  float64
#  31  gold_death                 499963 non-null  float64
#  32  gold_buyback               499963 non-null  float64
#  33  gold_abandon               499963 non-null  float64
#  34  gold_sell                  499963 non-null  float64
#  35  gold_destroying_structure  499963 non-null  float64
#  36  gold_killing_heros         499963 non-null  float64
#  37  gold_killing_creeps        499963 non-null  float64
#  38  gold_killing_roshan        499963 non-null  float64
#  39  gold_killing_couriers      499963 non-null  float64
# dtypes: float64(37), int64(1), object(2)
# memory usage: 156.4+ MB

# %%
full = pd.merge(match_results, full, how="left", left_on="match_id", right_on="match_id")
full.head(10)
# Out:
#    match_id  start_time  duration  tower_status_radiant  tower_status_dire  \
# 0         0  1446750112      2375                  1982                  4
# 1         0  1446750112      2375                  1982                  4
# 2         0  1446750112      2375                  1982                  4
# 3         0  1446750112      2375                  1982                  4
# 4         0  1446750112      2375                  1982                  4
# 5         0  1446750112      2375                  1982                  4
# 6         0  1446750112      2375                  1982                  4
# 7         0  1446750112      2375                  1982                  4
# 8         0  1446750112      2375                  1982                  4
# 9         0  1446750112      2375                  1982                  4
#
#    barracks_status_dire  barracks_status_radiant  first_blood_time  game_mode  \
# 0                     3                       63                 1         22
# 1                     3                       63                 1         22
# 2                     3                       63                 1         22
# 3                     3                       63                 1         22
# 4                     3                       63                 1         22
# 5                     3                       63                 1         22
# 6                     3                       63                 1         22
# 7                     3                       63                 1         22
# 8                     3                       63                 1         22
# 9                     3                       63                 1         22
#
#    radiant_win  ...  gold_other gold_death  gold_buyback  gold_abandon  \
# 0         True  ...         0.0    -3286.0         -39.0           0.0
# 1         True  ...       100.0    -2156.0           0.0           0.0
# 2         True  ...       107.0    -3682.0           0.0           0.0
# 3         True  ...       395.0    -1137.0           0.0           0.0
# 4         True  ...         0.0    -1437.0       -1056.0           0.0
# 5         True  ...      5679.0    -4039.0       -1063.0           0.0
# 6         True  ...       259.0    -1436.0       -1015.0           0.0
# 7         True  ...        50.0     -957.0           0.0           0.0
# 8         True  ...         0.0    -3287.0           0.0           0.0
# 9         True  ...         0.0    -2394.0       -2240.0           0.0
#
#    gold_sell  gold_destroying_structure  gold_killing_heros  \
# 0        0.0                      320.0              2127.0
# 1      938.0                     4714.0              4104.0
# 2      242.0                      695.0              4350.0
# 3     1650.0                     3299.0              6676.0
# 4     4194.0                     3217.0              7467.0
# 5      637.0                      320.0              2685.0
# 6        0.0                     3142.0              2418.0
# 7      212.0                     3120.0              5145.0
# 8      262.0                      320.0              3396.0
# 9      200.0                      320.0              5281.0
#
#    gold_killing_creeps  gold_killing_roshan  gold_killing_couriers
# 0               1089.0                  0.0                    0.0
# 1              10432.0                400.0                    0.0
# 2               8797.0                  0.0                    0.0
# 3               4317.0                937.0                    0.0
# 4               9220.0                400.0                    0.0
# 5               7011.0                  0.0                    0.0
# 6               3697.0                400.0                    0.0
# 7               1087.0                400.0                    0.0
# 8               4356.0                  0.0                    0.0
# 9               6193.0                  0.0                    0.0
#
# [10 rows x 49 columns]

# %%
full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 499963 entries, 0 to 499962
# Data columns (total 49 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   match_id                   499963 non-null  int64
#  1   start_time                 499963 non-null  int64
#  2   duration                   499963 non-null  int64
#  3   tower_status_radiant       499963 non-null  int64
#  4   tower_status_dire          499963 non-null  int64
#  5   barracks_status_dire       499963 non-null  int64
#  6   barracks_status_radiant    499963 non-null  int64
#  7   first_blood_time           499963 non-null  int64
#  8   game_mode                  499963 non-null  int64
#  9   radiant_win                499963 non-null  bool
#  10  hero_id                    499963 non-null  int64
#  11  localized_name             499963 non-null  object
#  12  account_id                 499963 non-null  float64
#  13  player_slot                499963 non-null  float64
#  14  gold                       499963 non-null  float64
#  15  gold_spent                 499963 non-null  float64
#  16  gold_per_min               499963 non-null  float64
#  17  xp_per_min                 499963 non-null  float64
#  18  kills                      499963 non-null  float64
#  19  deaths                     499963 non-null  float64
#  20  assists                    499963 non-null  float64
#  21  denies                     499963 non-null  float64
#  22  last_hits                  499963 non-null  float64
#  23  stuns                      499963 non-null  object
#  24  hero_damage                499963 non-null  float64
#  25  hero_healing               499963 non-null  float64
#  26  tower_damage               499963 non-null  float64
#  27  item_0                     499963 non-null  float64
#  28  item_1                     499963 non-null  float64
#  29  item_2                     499963 non-null  float64
#  30  item_3                     499963 non-null  float64
#  31  item_4                     499963 non-null  float64
#  32  item_5                     499963 non-null  float64
#  33  level                      499963 non-null  float64
#  34  leaver_status              499963 non-null  float64
#  35  xp_hero                    499963 non-null  float64
#  36  xp_creep                   499963 non-null  float64
#  37  xp_roshan                  499963 non-null  float64
#  38  xp_other                   499963 non-null  float64
#  39  gold_other                 499963 non-null  float64
#  40  gold_death                 499963 non-null  float64
#  41  gold_buyback               499963 non-null  float64
#  42  gold_abandon               499963 non-null  float64
#  43  gold_sell                  499963 non-null  float64
#  44  gold_destroying_structure  499963 non-null  float64
#  45  gold_killing_heros         499963 non-null  float64
#  46  gold_killing_creeps        499963 non-null  float64
#  47  gold_killing_roshan        499963 non-null  float64
#  48  gold_killing_couriers      499963 non-null  float64
# dtypes: bool(1), float64(36), int64(10), object(2)
# memory usage: 187.4+ MB

# %%
purchases = pd.merge(item_names, purchases, how="left", left_on="item_id", right_on="item_id")
purchases.head(10)
# Out:
#    item_id item_name    time  player_slot  match_id
# 0        1     blink   972.0          0.0       1.0
# 1        1     blink  1131.0          1.0       1.0
# 2        1     blink  1090.0        128.0       1.0
# 3        1     blink  1858.0        129.0       1.0
# 4        1     blink  2029.0        132.0       1.0
# 5        1     blink  2321.0        128.0       2.0
# 6        1     blink  1368.0        129.0       2.0
# 7        1     blink  1044.0          3.0       3.0
# 8        1     blink   916.0        128.0       3.0
# 9        1     blink  1238.0          0.0       4.0

# %%
full.describe()
# Out:
#             match_id    start_time       duration  tower_status_radiant  \
# count  499963.000000  4.999630e+05  499963.000000         499963.000000
# mean    24999.487052  1.447573e+09    2476.505537           1000.015513
# std     14433.737484  1.485254e+05     634.590836            948.202663
# min         0.000000  1.446750e+09      59.000000              0.000000
# 25%     12500.000000  1.447456e+09    2029.000000              0.000000
# 50%     24999.000000  1.447577e+09    2415.000000           1536.000000
# 75%     37499.500000  1.447700e+09    2872.000000           1974.000000
# max     49999.000000  1.447829e+09   16037.000000           2047.000000
#
#        tower_status_dire  barracks_status_dire  barracks_status_radiant  \
# count      499963.000000         499963.000000            499963.000000
# mean          935.231633             34.529223                34.775061
# std           937.963358             29.209408                29.731956
# min             0.000000              0.000000                 0.000000
# 25%             0.000000              0.000000                 0.000000
# 50%           384.000000             51.000000                51.000000
# 75%          1972.000000             63.000000                63.000000
# max          2047.000000             63.000000                63.000000
#
#        first_blood_time      game_mode        hero_id  ...     gold_other  \
# count     499963.000000  499963.000000  499963.000000  ...  499963.000000
# mean          93.825529      21.467961      50.555197  ...     399.994630
# std           92.649055       3.218345      32.807455  ...    1251.868403
# min            0.000000       2.000000       1.000000  ...    -100.000000
# 25%            9.000000      22.000000      21.000000  ...      61.000000
# 50%           77.000000      22.000000      47.000000  ...     166.000000
# 75%          144.000000      22.000000      75.000000  ...     336.000000
# max          831.000000      22.000000     112.000000  ...   30986.000000
#
#           gold_death   gold_buyback   gold_abandon      gold_sell  \
# count  499963.000000  499963.000000  499963.000000  499963.000000
# mean    -2654.886004    -337.238054      46.044769     523.608371
# std      1514.377458     665.372514     344.138879     944.612998
# min    -23757.000000  -22602.000000       0.000000       0.000000
# 25%     -3562.000000    -407.000000       0.000000      37.000000
# 50%     -2508.000000       0.000000       0.000000     235.000000
# 75%     -1550.000000       0.000000       0.000000     645.000000
# max         0.000000       0.000000   18339.000000  197237.000000
#
#        gold_destroying_structure  gold_killing_heros  gold_killing_creeps  \
# count              499963.000000       499963.000000        499963.000000
# mean                 2352.562644         4936.339893          5101.351496
# std                  1738.373273         2683.965056          3930.721501
# min                     0.000000            0.000000             0.000000
# 25%                   580.000000         3019.000000          2103.000000
# 50%                  2460.000000         4537.000000          4174.000000
# 75%                  3962.000000         6411.000000          7074.000000
# max                  7610.000000        37658.000000        112058.000000
#
#        gold_killing_roshan  gold_killing_couriers
# count        499963.000000          499963.000000
# mean            195.686843              38.215848
# std             255.287354              85.536828
# min               0.000000               0.000000
# 25%               0.000000               0.000000
# 50%             200.000000               0.000000
# 75%             383.000000               0.000000
# max            4227.000000            1725.000000
#
# [8 rows x 46 columns]

# %%
full.iloc[:,:27].iloc[:,14:].describe()
# Out:
#                 gold     gold_spent   gold_per_min     xp_per_min  \
# count  499963.000000  499963.000000  499963.000000  499963.000000
# mean     1888.656399   14111.088071     415.118485     450.005530
# std      1742.938033    6400.954875     138.192643     146.354295
# min         0.000000       0.000000     100.000000       0.000000
# 25%       586.000000    9590.000000     317.000000     343.000000
# 50%      1350.000000   13110.000000     395.000000     443.000000
# 75%      2742.000000   17635.000000     496.000000     550.000000
# max     46424.000000  200000.000000    1601.000000    1559.000000
#
#                kills         deaths        assists         denies  \
# count  499963.000000  499963.000000  499963.000000  499963.000000
# mean        7.405048       7.681320      11.762770       5.136270
# std         5.437630       3.807659       6.392811       5.898766
# min         0.000000       0.000000       0.000000       0.000000
# 25%         3.000000       5.000000       7.000000       1.000000
# 50%         6.000000       8.000000      11.000000       3.000000
# 75%        10.000000      10.000000      16.000000       7.000000
# max        59.000000      42.000000      54.000000     112.000000
#
#           last_hits    hero_damage   hero_healing   tower_damage
# count  499963.00000  499963.000000  499963.000000  499963.000000
# mean      129.49262   12235.683209     466.659459    1313.307419
# std       100.06011    6719.587039    1210.390898    1801.220324
# min         0.00000       0.000000       0.000000       0.000000
# 25%        54.00000    7309.000000       0.000000     118.000000
# 50%       105.00000   10947.000000       0.000000     554.000000
# 75%       178.00000   15874.000000     214.000000    1750.000000
# max      2000.00000   74932.000000   19222.000000   15986.000000

# %%
full.iloc[:,33:].describe()
# Out:
#                level  leaver_status        xp_hero       xp_creep  \
# count  499963.000000  499963.000000  499963.000000  499963.000000
# mean       18.053526       0.038643    8732.410270    9471.570736
# std         4.356836       0.283508    4879.040598    4422.375077
# min         1.000000       0.000000       0.000000       0.000000
# 25%        15.000000       0.000000    4995.000000    6128.000000
# 50%        18.000000       0.000000    8098.000000    8653.000000
# 75%        21.000000       0.000000   11922.000000   12077.000000
# max        25.000000       4.000000   29055.000000   31642.000000
#
#            xp_roshan      xp_other     gold_other     gold_death  \
# count  499963.000000  499963.00000  499963.000000  499963.000000
# mean      261.274138     429.75163     399.994630   -2654.886004
# std       476.442205    1111.51625    1251.868403    1514.377458
# min         0.000000       0.00000    -100.000000  -23757.000000
# 25%         0.000000     112.00000      61.000000   -3562.000000
# 50%         0.000000     280.00000     166.000000   -2508.000000
# 75%       447.000000     533.00000     336.000000   -1550.000000
# max      8050.000000   25557.00000   30986.000000       0.000000
#
#         gold_buyback   gold_abandon      gold_sell  gold_destroying_structure  \
# count  499963.000000  499963.000000  499963.000000              499963.000000
# mean     -337.238054      46.044769     523.608371                2352.562644
# std       665.372514     344.138879     944.612998                1738.373273
# min    -22602.000000       0.000000       0.000000                   0.000000
# 25%      -407.000000       0.000000      37.000000                 580.000000
# 50%         0.000000       0.000000     235.000000                2460.000000
# 75%         0.000000       0.000000     645.000000                3962.000000
# max         0.000000   18339.000000  197237.000000                7610.000000
#
#        gold_killing_heros  gold_killing_creeps  gold_killing_roshan  \
# count       499963.000000        499963.000000        499963.000000
# mean          4936.339893          5101.351496           195.686843
# std           2683.965056          3930.721501           255.287354
# min              0.000000             0.000000             0.000000
# 25%           3019.000000          2103.000000             0.000000
# 50%           4537.000000          4174.000000           200.000000
# 75%           6411.000000          7074.000000           383.000000
# max          37658.000000        112058.000000          4227.000000
#
#        gold_killing_couriers
# count          499963.000000
# mean               38.215848
# std                85.536828
# min                 0.000000
# 25%                 0.000000
# 50%                 0.000000
# 75%                 0.000000
# max              1725.000000

# %% [markdown]
# Number of unique account IDs in the database - note that this number is a bit lower than the number of unique players in the game, because some players have the Anonymous account option selected (making their account ID 0.0).

# %%
full.account_id.nunique()
# Out:
# 158356

# %%
#Let's get an idea of how often each hero is played. 

fig,ax = plt.subplots(figsize=(25,10))
full['localized_name'].value_counts(sort=False).plot(kind='bar',ax=ax,rot =90)
plt.title('Hero Distribution',fontsize=15)
plt.xlabel('Heroes',fontsize=15)
plt.ylabel('Frequency',fontsize=15)

#It looks like Windranger and Shadow Fiend are the two most popular heroes. To double check:

full.localized_name.value_counts().head(10)
# Out:
# Windranger       20881
# Shadow Fiend     17007
# Invoker          11676
# Earthshaker      11323
# Slardar          11181
# Queen of Pain    10590
# Juggernaut       10394
# Tusk             10306
# Alchemist         9823
# Pudge             9447
# Name: localized_name, dtype: int64

# %%
full.localized_name.value_counts().tail(10)
# Out:
# Batrider       1054
# Enchantress    1016
# Oracle         1009
# Naga Siren     1001
# Visage          997
# Lycan           985
# Lone Druid      967
# Brewmaster      931
# Elder Titan     838
# Chen            579
# Name: localized_name, dtype: int64

# %%
#Additionally, we find that the bottom 10 heroes are heroes that have complicated ability kits or have high minimum
#skill requirements. This doesn't come as a surprise - DotA is a difficult game to begin with. The addition of multiple
#units to control requires a lot of practice.

# %%
#First query to check out which account has the highest amount of total kills.

full.groupby(by = "account_id").sum().sort_values(by = "kills", ascending = False).kills.to_frame()
# Out:
#                 kills
# account_id
# 0.0         1347261.0
# 2962.0          595.0
# 732.0           545.0
# 4709.0          517.0
# 22106.0         517.0
# ...               ...
# 133626.0          0.0
# 100077.0          0.0
# 120709.0          0.0
# 7852.0            0.0
# 142614.0          0.0
#
# [158356 rows x 1 columns]

# %% [markdown]
# This doesn't give us what we want -- When player accounts are set to anonymous mode, their ID shows up as 0, crediting many unearned kills to one single account. Let's

# %%
#Let's use the pandas functionality to_frame() to convert this table to a dataframe. 

full.groupby(by = "account_id").mean().sort_values(by = "kills", ascending = False).kills.to_frame()
# Out:
#             kills
# account_id
# 145802.0     59.0
# 106851.0     50.0
# 44725.0      48.0
# 128032.0     46.0
# 18473.0      46.0
# ...           ...
# 87549.0       0.0
# 140167.0      0.0
# 140182.0      0.0
# 129349.0      0.0
# 117027.0      0.0
#
# [158356 rows x 1 columns]

# %% [markdown]
# Looking at this stats of heroes with the most kills.

# %%
full.groupby(by = "localized_name").mean().sort_values(by = "kills", ascending = False)
# Out:
#                          match_id    start_time     duration  \
# localized_name
# Riki                 24482.033092  1.447567e+09  2505.737198
# Ursa                 24651.429800  1.447569e+09  2425.123431
# Queen of Pain        25321.552502  1.447576e+09  2497.033050
# Templar Assassin     25487.378186  1.447578e+09  2370.016882
# Huskar               26945.018509  1.447592e+09  2398.309889
# ...                           ...           ...          ...
# Io                   24649.983471  1.447569e+09  2308.827037
# Omniknight           25103.810308  1.447574e+09  2411.735516
# Keeper of the Light  24063.038302  1.447563e+09  2525.346101
# Dazzle               25990.469832  1.447583e+09  2384.445198
# Treant Protector     25002.975890  1.447572e+09  2458.583812
#
#                      tower_status_radiant  tower_status_dire  \
# localized_name
# Riki                          1015.647826         925.924879
# Ursa                           971.672013         964.513017
# Queen of Pain                 1011.847403         923.798772
# Templar Assassin              1019.288150         926.094340
# Huskar                         965.614490         976.560550
# ...                                   ...                ...
# Io                            1019.923259         935.250295
# Omniknight                    1004.563457         941.506491
# Keeper of the Light            950.101061         972.957084
# Dazzle                         998.308699         942.859455
# Treant Protector               991.007463         961.494259
#
#                      barracks_status_dire  barracks_status_radiant  \
# localized_name
# Riki                            34.941063                35.846135
# Ursa                            35.374942                34.011623
# Queen of Pain                   34.222474                34.904249
# Templar Assassin                34.395233                35.376531
# Huskar                          36.000529                34.271549
# ...                                   ...                      ...
# Io                              35.341204                35.439787
# Omniknight                      34.520054                35.306530
# Keeper of the Light             35.477157                32.998154
# Dazzle                          34.854933                34.916577
# Treant Protector                35.592423                34.034443
#
#                      first_blood_time  game_mode  radiant_win  ...  \
# localized_name                                                 ...
# Riki                       102.278502  21.792271     0.526329  ...
# Ursa                        96.561599  21.660623     0.504881  ...
# Queen of Pain               90.268272  21.310670     0.524646  ...
# Templar Assassin           102.361304  21.513406     0.526812  ...
# Huskar                      92.712322  21.460603     0.496298  ...
# ...                               ...        ...          ...  ...
# Io                          86.438017  21.220779     0.526564  ...
# Omniknight                 105.451850  21.391591     0.517342  ...
# Keeper of the Light         90.760960  21.787725     0.497000  ...
# Dazzle                      93.797096  20.947995     0.516244  ...
# Treant Protector            92.032147  21.655568     0.513203  ...
#
#                      gold_other   gold_death  gold_buyback  gold_abandon  \
# localized_name
# Riki                 256.561836 -2678.187681   -346.750242     58.541304
# Ursa                 223.717341 -2761.736867   -425.349140     44.961181
# Queen of Pain        444.388763 -2666.166761   -385.298678     39.464873
# Templar Assassin     419.005131 -2656.374379   -457.680569     45.795432
# Huskar               165.078530 -3420.932311   -373.056584     50.346378
# ...                         ...          ...           ...           ...
# Io                   220.533058 -2463.187131   -272.629280     31.135183
# Omniknight           130.064716 -1988.224181   -153.613447     50.582445
# Keeper of the Light  163.099216 -2245.414398   -218.100138     60.604984
# Dazzle               154.684636 -2143.584910   -160.576699     36.188147
# Treant Protector     138.377727 -2009.976464   -189.188863     52.888060
#
#                       gold_sell  gold_destroying_structure  \
# localized_name
# Riki                 616.832367                2495.581401
# Ursa                 548.049977                2601.829614
# Queen of Pain        736.863456                2205.300472
# Templar Assassin     850.183217                2645.615856
# Huskar               500.440243                2442.130619
# ...                         ...                        ...
# Io                   278.570838                1944.681228
# Omniknight           274.973067                2390.957179
# Keeper of the Light  268.151361                2111.276419
# Dazzle               220.835059                2226.479591
# Treant Protector     252.779564                2221.135476
#
#                      gold_killing_heros  gold_killing_creeps  \
# localized_name
# Riki                        7142.634783          3802.800725
# Ursa                        5990.769177          5267.104835
# Queen of Pain               5870.112748          6309.448631
# Templar Assassin            5584.462761          7680.086726
# Huskar                      5727.444738          4725.174246
# ...                                 ...                  ...
# Io                          3639.295750          1079.623967
# Omniknight                  3695.238907          2004.756249
# Keeper of the Light         3456.411629          3473.271804
# Dazzle                      3288.648221          1635.113055
# Treant Protector            3288.564868          2421.895522
#
#                      gold_killing_roshan  gold_killing_couriers
# localized_name
# Riki                          196.640338              32.041063
# Ursa                          887.241283              37.255927
# Queen of Pain                 182.393673              34.220491
# Templar Assassin              371.374048              31.790798
# Huskar                        257.989688              37.082232
# ...                                  ...                    ...
# Io                            159.988194              38.007674
# Omniknight                    163.149196              39.704515
# Keeper of the Light           149.889709              43.368713
# Dazzle                        175.809949              40.996668
# Treant Protector              147.679679              45.602755
#
# [110 rows x 47 columns]

# %% [markdown]
# Heroes with the most damage - note that many of the heroes with the most kills do not have the highest amounts of damage. *But*, heroes with low damage generally also have low kills.

# %%
full.groupby(by = "localized_name").mean().sort_values(by = "hero_damage", ascending = False)
# Out:
#                       match_id    start_time     duration  \
# localized_name
# Zeus              24497.217912  1.447568e+09  2580.488342
# Tinker            24443.425670  1.447567e+09  2616.057088
# Spectre           24812.206607  1.447571e+09  2538.711862
# Gyrocopter        25462.236727  1.447578e+09  2529.441074
# Shadow Fiend      25050.110308  1.447574e+09  2434.263421
# ...                        ...           ...          ...
# Io                24649.983471  1.447569e+09  2308.827037
# Chen              25791.727116  1.447582e+09  2406.373057
# Omniknight        25103.810308  1.447574e+09  2411.735516
# Dazzle            25990.469832  1.447583e+09  2384.445198
# Treant Protector  25002.975890  1.447572e+09  2458.583812
#
#                   tower_status_radiant  tower_status_dire  \
# localized_name
# Zeus                       1008.669645         917.606232
# Tinker                      991.374330         957.017625
# Spectre                    1013.907958         921.776577
# Gyrocopter                  980.373104         946.780484
# Shadow Fiend                996.095666         942.737696
# ...                                ...                ...
# Io                         1019.923259         935.250295
# Chen                        986.656304         948.981002
# Omniknight                 1004.563457         941.506491
# Dazzle                      998.308699         942.859455
# Treant Protector            991.007463         961.494259
#
#                   barracks_status_dire  barracks_status_radiant  \
# localized_name
# Zeus                         34.166921                35.078448
# Tinker                       34.675096                34.496935
# Spectre                      34.233934                35.000601
# Gyrocopter                   34.888127                34.314323
# Shadow Fiend                 34.506380                34.437702
# ...                                ...                      ...
# Io                           35.341204                35.439787
# Chen                         35.594128                34.056995
# Omniknight                   34.520054                35.306530
# Dazzle                       34.854933                34.916577
# Treant Protector             35.592423                34.034443
#
#                   first_blood_time  game_mode  radiant_win  ...  gold_other  \
# localized_name                                              ...
# Zeus                     96.250599  21.542384     0.525605  ...  345.544127
# Tinker                   90.643295  21.747126     0.509195  ...  171.613793
# Spectre                  96.001351  21.582583     0.527477  ...  145.881231
# Gyrocopter               90.779901  21.066511     0.510356  ...  208.162048
# Shadow Fiend             93.667137  21.543717     0.516493  ...  382.047333
# ...                            ...        ...          ...  ...         ...
# Io                       86.438017  21.220779     0.526564  ...  220.533058
# Chen                    104.908463  21.792746     0.514680  ...  138.820380
# Omniknight              105.451850  21.391591     0.517342  ...  130.064716
# Dazzle                   93.797096  20.947995     0.516244  ...  154.684636
# Treant Protector         92.032147  21.655568     0.513203  ...  138.377727
#
#                    gold_death  gold_buyback  gold_abandon    gold_sell  \
# localized_name
# Zeus             -2683.375681   -342.672478     46.946611   457.817825
# Tinker           -2929.552874   -524.010345     59.852874   293.777011
# Spectre          -2402.320270   -435.308258     44.945345   644.515766
# Gyrocopter       -2816.290694   -407.683343     40.286173   738.548133
# Shadow Fiend     -2881.394191   -431.210796     45.046451  1065.254307
# ...                       ...           ...           ...          ...
# Io               -2463.187131   -272.629280     31.135183   278.570838
# Chen             -2073.376511   -145.431779     26.955095   227.974093
# Omniknight       -1988.224181   -153.613447     50.582445   274.973067
# Dazzle           -2143.584910   -160.576699     36.188147   220.835059
# Treant Protector -2009.976464   -189.188863     52.888060   252.779564
#
#                   gold_destroying_structure  gold_killing_heros  \
# localized_name
# Zeus                            2310.194596         6014.217477
# Tinker                          1937.692720         5626.362452
# Spectre                         2556.867568         5923.536787
# Gyrocopter                      2566.226371         5163.311260
# Shadow Fiend                    2776.299524         5258.232728
# ...                                     ...                 ...
# Io                              1944.681228         3639.295750
# Chen                            2241.799655         3120.970639
# Omniknight                      2390.957179         3695.238907
# Dazzle                          2226.479591         3288.648221
# Treant Protector                2221.135476         3288.564868
#
#                   gold_killing_creeps  gold_killing_roshan  \
# localized_name
# Zeus                      4238.592940           158.658967
# Tinker                    7727.580077           133.237548
# Spectre                   8226.937387           168.464414
# Gyrocopter                8734.192386           219.751021
# Shadow Fiend              9571.285823           255.814253
# ...                               ...                  ...
# Io                        1079.623967           159.988194
# Chen                      3051.813472           174.625216
# Omniknight                2004.756249           163.149196
# Dazzle                    1635.113055           175.809949
# Treant Protector          2421.895522           147.679679
#
#                   gold_killing_couriers
# localized_name
# Zeus                          40.326869
# Tinker                        40.101533
# Spectre                       37.327327
# Gyrocopter                    36.481914
# Shadow Fiend                  33.070206
# ...                                 ...
# Io                            38.007674
# Chen                          36.908463
# Omniknight                    39.704515
# Dazzle                        40.996668
# Treant Protector              45.602755
#
# [110 rows x 47 columns]

# %% [markdown]
# Hero with the most last hits on average

# %%
full.groupby(by = "localized_name").mean().sort_values(by = "last_hits", ascending = False)
# Out:
#                     match_id    start_time     duration  tower_status_radiant  \
# localized_name
# Anti-Mage       25174.778523  1.447575e+09  2428.659430           1000.316305
# Alchemist       25367.509417  1.447577e+09  2436.046727            992.696020
# Medusa          24601.650000  1.447570e+09  2571.579661            993.897458
# Shadow Fiend    25050.110308  1.447574e+09  2434.263421            996.095666
# Luna            25246.649706  1.447576e+09  2455.324222           1021.579899
# ...                      ...           ...          ...                   ...
# Skywrath Mage   25041.077957  1.447573e+09  2477.218078            985.305108
# Disruptor       24787.915158  1.447571e+09  2471.382737            985.244000
# Lion            24702.015037  1.447570e+09  2504.416689           1009.722027
# Bane            26172.166079  1.447585e+09  2484.794360            998.403447
# Io              24649.983471  1.447569e+09  2308.827037           1019.923259
#
#                 tower_status_dire  barracks_status_dire  \
# localized_name
# Anti-Mage              925.138570             33.580673
# Alchemist              935.746717             33.956632
# Medusa                 932.395763             34.128390
# Shadow Fiend           942.737696             34.506380
# Luna                   905.775442             34.177040
# ...                           ...                   ...
# Skywrath Mage          958.315524             35.263105
# Disruptor              945.379158             34.983368
# Lion                   925.012598             34.290030
# Bane                   935.880924             34.847630
# Io                     935.250295             35.341204
#
#                 barracks_status_radiant  first_blood_time  game_mode  \
# localized_name
# Anti-Mage                     34.276713        101.257663  21.693487
# Alchemist                     34.205640         92.538023  21.749567
# Medusa                        34.416949         96.909746  21.372881
# Shadow Fiend                  34.437702         93.667137  21.543717
# Luna                          35.840202         94.231287  21.411270
# ...                                 ...               ...        ...
# Skywrath Mage                 34.329973         91.999664  21.543011
# Disruptor                     34.180000         88.797684  21.065263
# Lion                          35.107153         92.634516  21.322677
# Bane                          35.143361         95.363494  20.926753
# Io                            35.439787         86.438017  21.220779
#
#                 radiant_win  ...   gold_other   gold_death  gold_buyback  \
# localized_name               ...
# Anti-Mage          0.521392  ...   215.145594 -2222.283099   -384.869625
# Alchemist          0.517866  ...  7951.188028 -2808.196987   -577.051919
# Medusa             0.518220  ...   203.275000 -2101.389407   -320.507203
# Shadow Fiend       0.516493  ...   382.047333 -2881.394191   -431.210796
# Luna               0.534062  ...   174.258200 -2770.528175   -358.230025
# ...                     ...  ...          ...          ...           ...
# Skywrath Mage      0.512097  ...   197.881720 -2662.056788   -264.049059
# Disruptor          0.514737  ...   168.249263 -2467.338947   -189.162105
# Lion               0.524248  ...   174.273503 -2650.554728   -262.043213
# Bane               0.516647  ...   188.609087 -2387.558950   -227.649040
# Io                 0.526564  ...   220.533058 -2463.187131   -272.629280
#
#                 gold_abandon    gold_sell  gold_destroying_structure  \
# localized_name
# Anti-Mage          47.083546   642.357173                2637.048425
# Alchemist          51.761682   833.557976                2613.759748
# Medusa             40.856356   627.953814                2634.196186
# Shadow Fiend       45.046451  1065.254307                2776.299524
# Luna               43.211522   660.051724                2967.167368
# ...                      ...          ...                        ...
# Skywrath Mage      50.528226   347.391801                1956.938508
# Disruptor          46.946316   240.482105                2191.615368
# Lion               45.305879   272.012598                2027.542265
# Bane               34.850764   290.524873                2107.645515
# Io                 31.135183   278.570838                1944.681228
#
#                 gold_killing_heros  gold_killing_creeps  gold_killing_roshan  \
# localized_name
# Anti-Mage              4229.203597         11546.072584           186.587058
# Alchemist              3965.879772         10292.677492           166.661509
# Medusa                 4145.446610         10188.130932           168.092373
# Shadow Fiend           5258.232728          9571.285823           255.814253
# Luna                   4786.394449          9120.392347           206.241800
# ...                            ...                  ...                  ...
# Skywrath Mage          5058.963710          1502.428763           154.264785
# Disruptor              4299.657474          1438.620421           164.028632
# Lion                   4403.495530          1372.776348           159.456109
# Bane                   4291.962397          1217.792793           171.187622
# Io                     3639.295750          1079.623967           159.988194
#
#                 gold_killing_couriers
# localized_name
# Anti-Mage                   37.405811
# Alchemist                   34.195765
# Medusa                      39.542373
# Shadow Fiend                33.070206
# Luna                        39.831791
# ...                               ...
# Skywrath Mage               37.864583
# Disruptor                   40.526316
# Lion                        41.621512
# Bane                        42.267920
# Io                          38.007674
#
# [110 rows x 47 columns]

# %% [markdown]
# Heroes with the highest gold-per-minute (GPM)

# %%
full.groupby(by = "localized_name").mean().sort_values(by = "gold_per_min", ascending = False)
# Out:
#                       match_id    start_time     duration  \
# localized_name
# Alchemist         25367.509417  1.447577e+09  2436.046727
# Anti-Mage         25174.778523  1.447575e+09  2428.659430
# Shadow Fiend      25050.110308  1.447574e+09  2434.263421
# Templar Assassin  25487.378186  1.447578e+09  2370.016882
# Meepo             24413.823952  1.447567e+09  2369.988024
# ...                        ...           ...          ...
# Lion              24702.015037  1.447570e+09  2504.416689
# Bane              26172.166079  1.447585e+09  2484.794360
# Shadow Demon      24694.931183  1.447571e+09  2481.109677
# Dazzle            25990.469832  1.447583e+09  2384.445198
# Io                24649.983471  1.447569e+09  2308.827037
#
#                   tower_status_radiant  tower_status_dire  \
# localized_name
# Alchemist                   992.696020         935.746717
# Anti-Mage                  1000.316305         925.138570
# Shadow Fiend                996.095666         942.737696
# Templar Assassin           1019.288150         926.094340
# Meepo                       966.201796         958.840120
# ...                                ...                ...
# Lion                       1009.722027         925.012598
# Bane                        998.403447         935.880924
# Shadow Demon                969.197849         959.385663
# Dazzle                      998.308699         942.859455
# Io                         1019.923259         935.250295
#
#                   barracks_status_dire  barracks_status_radiant  \
# localized_name
# Alchemist                    33.956632                34.205640
# Anti-Mage                    33.580673                34.276713
# Shadow Fiend                 34.506380                34.437702
# Templar Assassin             34.395233                35.376531
# Meepo                        34.847904                34.288623
# ...                                ...                      ...
# Lion                         34.290030                35.107153
# Bane                         34.847630                35.143361
# Shadow Demon                 35.205018                33.855914
# Dazzle                       34.854933                34.916577
# Io                           35.341204                35.439787
#
#                   first_blood_time  game_mode  radiant_win  ...   gold_other  \
# localized_name                                              ...
# Alchemist                92.538023  21.749567     0.517866  ...  7951.188028
# Anti-Mage               101.257663  21.693487     0.521392  ...   215.145594
# Shadow Fiend             93.667137  21.543717     0.516493  ...   382.047333
# Templar Assassin        102.361304  21.513406     0.526812  ...   419.005131
# Meepo                   102.107784  21.664671     0.497605  ...   191.770659
# ...                            ...        ...          ...  ...          ...
# Lion                     92.634516  21.322677     0.524248  ...   174.273503
# Bane                     95.363494  20.926753     0.516647  ...   188.609087
# Shadow Demon             85.049462  21.455197     0.502509  ...   177.667384
# Dazzle                   93.797096  20.947995     0.516244  ...   154.684636
# Io                       86.438017  21.220779     0.526564  ...   220.533058
#
#                    gold_death  gold_buyback  gold_abandon    gold_sell  \
# localized_name
# Alchemist        -2808.196987   -577.051919     51.761682   833.557976
# Anti-Mage        -2222.283099   -384.869625     47.083546   642.357173
# Shadow Fiend     -2881.394191   -431.210796     45.046451  1065.254307
# Templar Assassin -2656.374379   -457.680569     45.795432   850.183217
# Meepo            -3610.622754   -723.254491     56.491617   540.966467
# ...                       ...           ...           ...          ...
# Lion             -2650.554728   -262.043213     45.305879   272.012598
# Bane             -2387.558950   -227.649040     34.850764   290.524873
# Shadow Demon     -2638.780645   -215.801434     41.939785   254.582796
# Dazzle           -2143.584910   -160.576699     36.188147   220.835059
# Io               -2463.187131   -272.629280     31.135183   278.570838
#
#                   gold_destroying_structure  gold_killing_heros  \
# localized_name
# Alchemist                       2613.759748         3965.879772
# Anti-Mage                       2637.048425         4229.203597
# Shadow Fiend                    2776.299524         5258.232728
# Templar Assassin                2645.615856         5584.462761
# Meepo                           2575.946707         5197.710778
# ...                                     ...                 ...
# Lion                            2027.542265         4403.495530
# Bane                            2107.645515         4291.962397
# Shadow Demon                    1853.930466         3861.003584
# Dazzle                          2226.479591         3288.648221
# Io                              1944.681228         3639.295750
#
#                   gold_killing_creeps  gold_killing_roshan  \
# localized_name
# Alchemist                10292.677492           166.661509
# Anti-Mage                11546.072584           186.587058
# Shadow Fiend              9571.285823           255.814253
# Templar Assassin          7680.086726           371.374048
# Meepo                     8243.145509           284.844910
# ...                               ...                  ...
# Lion                      1372.776348           159.456109
# Bane                      1217.792793           171.187622
# Shadow Demon              1904.924731           149.517563
# Dazzle                    1635.113055           175.809949
# Io                        1079.623967           159.988194
#
#                   gold_killing_couriers
# localized_name
# Alchemist                     34.195765
# Anti-Mage                     37.405811
# Shadow Fiend                  33.070206
# Templar Assassin              31.790798
# Meepo                         33.739521
# ...                                 ...
# Lion                          41.621512
# Bane                          42.267920
# Shadow Demon                  39.189964
# Dazzle                        40.996668
# Io                            38.007674
#
# [110 rows x 47 columns]

# %% [markdown]
# Number of Radiant wins

# %%
rwins = len(match_results.loc[match_results.radiant_win == True])
print('{:.2f}'.format(rwins))
# Out:
# 25943.00

# %% [markdown]
# Number of Dire wins

# %%
dwins = len(match_results.loc[match_results.radiant_win == False])
print('{:.2f}'.format(dwins))
# Out:
# 24057.00

# %%
print('Do both teams have an equal number of wins? {}'.format(
    round(len(match_results.loc[match_results.radiant_win == True])/len(match_results.loc[match_results.radiant_win == False]), 1) == 1
))
print('How significant of an advantage does Radiant have? {}%'.format(
    round(len(match_results.loc[match_results.radiant_win == True])/len(match_results.loc[match_results.radiant_win == False]) - 1, 3) * 100
))

#Bar chart for number of wins of each side
y = match_results['radiant_win'].apply(lambda win: True if win else False)
classes = ['Dire Win', 'Radiant Win']
_ = pd.Series(y).apply(lambda i: classes[i]).value_counts().plot(kind = 'bar')



rwinpct = rwins/(rwins+dwins)*100
dwinpct = dwins/(rwins+dwins)*100
windiff = rwinpct - dwinpct

print ('Radiant wins', '{:.2f}'.format(rwinpct), 'percent of their games')
print('Dire wins', '{:.2f}'.format(dwinpct), 'percent of their games')
print('Difference = ''{:.2f}'.format(windiff))
# Out:
# Do both teams have an equal number of wins? False
# How significant of an advantage does Radiant have? 7.8%
# Radiant wins 51.89 percent of their games
# Dire wins 48.11 percent of their games
# Difference = 3.77

# %%
#Pie chart for number of wins of each side
X = [match_results.radiant_win[(match_results['radiant_win']==True)].count(),match_results.radiant_win[(match_results['radiant_win']==False)].count()]
Y = ["RadiantWin","DireWin"]
plt.pie(X, labels=Y, startangle=90, autopct='%.1f%%')
plt.show()
plt.ioff()

# %% [markdown]
# What could be the explanation for this difference in win percentage ( between the two sides? Some hypotheses:
#
# 1. Roshan access. Roshan is an important objective in DotA 2, and the Radiant side has easier access to the entrance of Roshan's pit.
#
# 2. Ancient camp location. The Ancient neutral camp in DotA 2 provides the highest gold and experience bounties. The location of these camps matters, and Dire's camp is farthest away from Roshan's pit. This means that anyone attacking the Ancient camp has a longer distance to run to Roshan's pit than someone at the Radiant ancient camp.
#
# 3. Camera angle. Some argue that the camera angle in DotA 2, which is not adjustable, favors Radiant more due to it being easier for most players to move their camera up rather than down. (Radiant gameflow typically goes from bottom to top and Dire's gameflow goes from top to bottom.

# %%
y = match_results['radiant_win'].apply(lambda win: True if win else False)
classes = ['Dire Win', 'Radiant Win']
_ = pd.Series(y).apply(lambda i: classes[i]).value_counts().plot(kind = 'bar')

# %%
#Most commonly purchased items.

purchases.item_name.value_counts().to_frame().head(10)
# Out:
#                 item_name
# tpscroll          3864464
# ward_observer     1214710
# branches           745330
# boots              551272
# tango              490735
# ward_sentry        466971
# ward_dispenser     453635
# circlet            412626
# clarity            369774
# ogre_axe           300991

# %% [markdown]
# Some interesting results - there are 50,000 games in the database, but there are 551,272 boot purchases. Heroes in DotA 2 only benefit from buying one pair of boots, so there really shouldn't be more than 500,000 boots. What accounts for the other 51,272 boot purchases? It may involve buying a different pair of boots to benefit from different stats, but most likely, it's players buying Boots of Travel, the most expensive boots in the game, in the lategame. So players start off with one pair, and then once the late game comes around and players have more gold, they opt to purchase Boots of Travel.

# %%
purchases.item_name.value_counts().to_frame().tail(10)

#These least common items include unreleased items. ?
# Out:
#                    item_name
# aegis                      1
# halloween_rapier           1
# winter_ham                 1
# greevil_whistle            1
# iron_talon                 1
# faerie_fire                1
# tome_of_knowledge          1
# cheese                     1
# aether_lens                1
# winter_coco                1

# %%
fig,ax = plt.subplots(figsize=(30,20))
purchases['item_name'].value_counts(sort=False).plot(kind='bar',ax=ax,rot =90)
plt.title('Item Distribution',fontsize=15)
plt.xlabel('Items',fontsize=15)
plt.ylabel('Frequency',fontsize=15)
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# Now, we will look to see if we can find and understand some correlated variables in the data. DotA has a virtually limitless supply of variables and timings to investigate, so for now let's just scratch the surface of some of the hard-coded data.

# %%
corrMatrix = games.corr()
f, ax = plt.subplots(figsize=(40, 30))
sns.heatmap(corrMatrix, linewidths=.5, annot=True)
plt.show()

# %% [markdown]
# Now, this is just a bit too much to look at. Some of the stats are obvious/unhelpful - it should be self-evident that level and xp per minute are highly correlated (after all, they are dependent :)). Let's trim some of the columns that we don't want to look at for now.
#
# Additionally, let's cut some of the obviously dependent variables (xp per minute and level, for instance.)

# %% [markdown]
# asfdasfdasd not

# %%
corrMatrix = match_results.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %% [markdown]
# We notice that tower_status_radiant and radiant_win are strongly correlated - As radiant's towers stay up, Radiant has a higher chance of winning. Contrapositively, Radiant has a lower chance of winning as its towers fall. Also note that tower_status_dire and radiant_win are *inversely* correlated. That is nearly self-evident - as Radiant captures Dire towers, tower_status_dire decreases, and radiant_win increases.
#
# Towers in DotA are extremely important for strategic purposes, but they're also a hard-coded rule for winning - at least one full lane and the throne towers of one's opponent must be destroyed in order for one'es team to win.
